# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# Aluno: Raul Pichinin

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Amazon Web Services;</li>
#   <li>AWS IAM;</li>
#   <li>AWS S3;</li>
#   <li>AWS Athena.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Amazon Web Services

# %% [markdown]
#  1. Crie uma conta na [AWS](https://portal.aws.amazon.com/);
#  1. Acesse a sua conta e selecione a região mais próxima da sua residência.

# %% [markdown]
# ![imagem 1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2\. AWS S3

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.

# %%
import pandas as pd
import seaborn as sns

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.to_csv('iris.csv', index=False, header=False)

# %% [markdown]
#  **Obs:** Criando pasta e carregando 'iris' arquivo no S3:

# %% [markdown]
# ![imgem2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![imagem 3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Obs:** Criando um bucket no AWS S3 para armazenar os resultados;

# %% [markdown]
# ![abc.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3\. AWS Athena

# %% [markdown]
# **Obs:** Configurando o AWS Athena para utilizar o bucket resultados;

# %% [markdown]
# ![athena1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Obs:** Criando uma tabela SQL utilizando o bucket da aula 3, item 3.3

# %% [markdown]
# ![criando tabela iris.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Obs:** Executando consultas SQL no Athena;

# %% [markdown]
# ![consulta_sql_2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![cnstl.JPG](data:image/jpeg;base64,...)
